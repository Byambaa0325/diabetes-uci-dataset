# %% [markdown]
# # Experiment: SVM Baseline (stratified 15k subsample)
#
# RBF-kernel SVM on a stratified 15k subsample of training data. Val set is the full holdout.
#
# **Expected runtime:** ~5–15 min on CPU.

# %%
import sys, os
if 'google.colab' in str(get_ipython()):
    REPO = 'diabetes-uci-dataset'
    REPO_URL = 'https://github.com/byambaa0325/diabetes-uci-dataset.git'
    if not os.path.exists(REPO):
        os.system(f'git clone {REPO_URL}')
    os.chdir(REPO)
    os.system('pip install -q -r requirements.txt')
    os.system('pip install -q -e .')
else:
    root = os.path.abspath(os.path.join(os.getcwd(), '../../'))
    if root not in sys.path:
        sys.path.insert(0, root)

# %%
from src.pipeline import run_pipeline

# %%
config = {
    'name':          'svm_rbf_v2',
    'wandb_project': 'applied-ai-coursework',
    'model':         'svm',
    'subsample':     15_000,
    'model_params':  {
        'kernel':       'rbf',
        'C':            1.0,
        'gamma':        'scale',
        'probability':  True,
        'class_weight': 'balanced',
    },
    'plot': True,
}

# %%
result = run_pipeline(config)

m = result.metrics
print(f"\nROC-AUC    : {m['roc_auc']:.4f}")
print(f"Threshold  : {m['threshold']:.3f}")
print(f"F1         : {m['f1']:.4f}")
print(f"Recall     : {m['recall']:.4f}")
print(f"Recall(<30): {m['recall_lt30']:.4f}")
print(f"Precision  : {m['precision']:.4f}")
print(f"Run dir    : {result.run_dir}")
print(f"Time       : {result.elapsed_s:.1f}s")
