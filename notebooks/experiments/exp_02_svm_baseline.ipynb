# %% [markdown]
# # Experiment: SVM Baseline
#
# RBF-kernel SVM as a non-linear baseline. SVM doesn't scale well (O(n²) memory), so we train on a stratified subsample of 15k rows. Val set stays the full holdout for fair comparison with other experiments.

# %%
import sys, os
if 'google.colab' in str(get_ipython()):
    REPO = 'diabetes-uci-dataset'
    REPO_URL = 'https://github.com/byambaa0325/diabetes-uci-dataset.git'
    if not os.path.exists(REPO):
        os.system(f'git clone {REPO_URL}')
    os.chdir(REPO)
    os.system('pip install -q -r requirements.txt')
    os.system('pip install -q -e .')
else:
    root = os.path.abspath(os.path.join(os.getcwd(), '../../'))
    if root not in sys.path:
        sys.path.insert(0, root)

# %%
import numpy as np
from sklearn.utils import resample

from src.data.loader import load_raw
from src.data.preprocessor import clean, encode_target
from src.data.features import build_features
from src.models.trainers import run_training
from src.evaluation.metrics import evaluate

# %%
# --- Data ---
df_raw, _ = load_raw()
df = encode_target(clean(df_raw))

split = int(0.8 * len(df))
df_train, df_val = df.iloc[:split].copy(), df.iloc[split:].copy()

X_train_full, y_train_full, scaler = build_features(df_train, fit_scaler=True)
X_val,        y_val,        _      = build_features(df_val, scaler=scaler, fit_scaler=False)

# Stratified subsample — SVM is O(n²), 15k is a practical ceiling without special solvers
SUBSAMPLE = 15_000
X_train, y_train = resample(
    X_train_full, y_train_full,
    n_samples=SUBSAMPLE,
    stratify=y_train_full,
    random_state=42,
)

pos_rate = y_train.mean()
print(f'Train subsample: {X_train.shape}  (positive rate: {pos_rate:.3f})')
print(f'Val:             {X_val.shape}')
# Out:
# Train subsample: (15000, 41)  (positive rate: 0.094)
# Val:             (14304, 41)

# %%
# --- Config ---
config = {
    'name':          'svm_rbf_baseline',
    'wandb_project': 'applied-ai-coursework',
    'model':         'svm',
    'model_params':  {
        'kernel':      'rbf',
        'C':           1.0,
        'gamma':       'scale',
        'probability': True,   # required for predict_proba / ROC-AUC
        'class_weight': 'balanced',  # handles the 11% positive class imbalance
    },
    'X_train': X_train, 'y_train': y_train,
    'X_val':   X_val,   'y_val':   y_val,
}

# %%
# --- Train (grab a coffee) ---
import time
t0 = time.time()
run_dir = run_training(config)
print(f'Training time: {time.time() - t0:.1f}s')
print('Artefacts saved to:', run_dir)
# Out:
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from C:\Users\byamb\_netrc.
# wandb: Currently logged in as: byambaa-bayarmandakh-25 (byambaa-bayarmandakh-25-ucl) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.25.0
# Run data is saved locally in <code>e:\UCL-Workspaces\applied-ai-coursework\notebooks\experiments\wandb\run-20260307_190822-qh1e5i9s</code>
# Syncing run <strong><a href='https://wandb.ai/byambaa-bayarmandakh-25-ucl/applied-ai-coursework/runs/qh1e5i9s' target="_blank">svm_rbf_baseline_2026-03-07_19-08-21</a></strong> to <a href='https://wandb.ai/byambaa-bayarmandakh-25-ucl/applied-ai-coursework' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/byambaa-bayarmandakh-25-ucl/applied-ai-coursework' target="_blank">https://wandb.ai/byambaa-bayarmandakh-25-ucl/applied-ai-coursework</a>
#  View run at <a href='https://wandb.ai/byambaa-bayarmandakh-25-ucl/applied-ai-coursework/runs/qh1e5i9s' target="_blank">https://wandb.ai/byambaa-bayarmandakh-25-ucl/applied-ai-coursework/runs/qh1e5i9s</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>train_log_loss</td><td>▁</td></tr><tr><td>val_log_loss</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>train_log_loss</td><td>0.29559</td></tr><tr><td>val_log_loss</td><td>0.24334</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">svm_rbf_baseline_2026-03-07_19-08-21</strong> at: <a href='https://wandb.ai/byambaa-bayarmandakh-25-ucl/applied-ai-coursework/runs/qh1e5i9s' target="_blank">https://wandb.ai/byambaa-bayarmandakh-25-ucl/applied-ai-coursework/runs/qh1e5i9s</a><br> View project at: <a href='https://wandb.ai/byambaa-bayarmandakh-25-ucl/applied-ai-coursework' target="_blank">https://wandb.ai/byambaa-bayarmandakh-25-ucl/applied-ai-coursework</a><br>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20260307_190822-qh1e5i9s\logs</code>
# Run saved → E:\UCL-Workspaces\applied-ai-coursework\runs\2026-03-07_19-08-21_svm_rbf_baseline
# Training time: 89.7s
# Artefacts saved to: E:\UCL-Workspaces\applied-ai-coursework\runs\2026-03-07_19-08-21_svm_rbf_baseline

# %%
# --- Evaluate ---
import joblib
model = joblib.load(run_dir / 'model.joblib')

results = evaluate(model, X_val, y_val, threshold=None, plot=True, title=config['name'])

print(f"ROC-AUC  : {results['roc_auc']:.4f}")
print(f"Threshold: {results['threshold']:.3f}")
print(f"F1       : {results['f1']:.4f}")
print(f"Recall   : {results['recall']:.4f}")
print(f"Precision: {results['precision']:.4f}")
# Out:
# ROC-AUC  : 0.5907
# Threshold: 0.125
# F1       : 0.1527
# Recall   : 0.2674
# Precision: 0.1068
